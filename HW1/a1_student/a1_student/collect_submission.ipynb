# %%
from google.colab import drive

drive.mount('/content/drive')

# TODO: Enter the path in your Drive of the assignment.
# e.g. 'csep590a/assignments/assignment2/'
FOLDERNAME = None

assert FOLDERNAME is not None, "[!] Enter the foldername."

# %% [markdown]
# # Collect Submission - Zip
#
# Run this notebook once you have completed all the other notebooks: `two_layer_net.ipynb`, `features.ipynb`, and `FullyConnectedNets.ipynb`.
#
# It will generate a zip file of your code (`.py` and `.ipynb`) called `a1_code_submission.zip`.
#
# If your submission for this step was successful, you should see the following display message:
#
# `### Done! Please submit a1_code_submission.zip to Gradescope. ###`
#
# Make sure to download the zip file locally to your computer, then submit to Gradescope. Congrats on succesfully completing the assignment!

# %%
# %cd drive/My\ Drive
# %cd $FOLDERNAME
# !sudo apt-get update
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-latex-recommended
# !pip install PyPDF2
# !bash collectSubmission.sh
